# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a pretrained segmentation model like YOLO26n-seg
model = YOLO("yolo26n-seg.pt")  # load a pretrained model (recommended for training)

# Train the model on the Carparts Segmentation dataset
results = model.train(data="carparts-seg.yaml", epochs=10, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# After training, you can validate the model's performance on the validation set
results = model.val()
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n-seg summary (fused): 139 layers, 2,693,369 parameters, 0 gradients, 9.0 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1365.0±576.5 MB/s, size: 40.5 KB)
# val: Scanning /content/datasets/carparts-seg/labels/val.cache... 401 images, 12 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 401/401 140.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 2.6it/s 9.9s
#                    all        401       2042      0.476      0.608      0.552      0.451      0.485      0.615      0.562       0.44
#            back_bumper         94         94      0.732      0.844      0.853      0.631      0.732      0.843      0.852      0.619
#              back_door        158        159      0.707       0.79      0.779      0.647      0.706      0.786      0.779      0.629
# ...

# %%
# Or perform prediction on new images or videos
results = model.predict("/content/datasets/carparts-seg/images/test/te28_jpg.rf.5e18a17dba9901dd746219528e7e359c.jpg",save=True,conf=0.2)
#the picture in the location will be copied in the runs>>predict file
# Out:
# image 1/1 /content/datasets/carparts-seg/images/test/te28_jpg.rf.5e18a17dba9901dd746219528e7e359c.jpg: 640x640 1 front_bumper, 1 front_door, 1 front_glass, 1 front_light, 1 hood, 11.6ms
# Speed: 1.6ms preprocess, 11.6ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/segment/predict
